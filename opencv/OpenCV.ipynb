# %% [markdown]
# # Image?
# * combination of multiple pixels .in python img stored in 2d array. array exist in numpy
#
# # Pixel ?
# * a smallest item in an img,2d grid represntaion using squares : pix:pictures,el:element
#
# # OpenCV-open source computer vision library ?-dveloped by intel
# * supports c,C++,Python
#
# * gives the system the ability to identify faces or other objects.
#
# # Computer Vision?
# * is process taht involves capturing,processing and analysing real-world images and video to allow mlc's to extract meaningful
#
# * interlink up with  in artificial intelligence, machine learning, facial recognition
#
# # Two primary tasks :
#
# * **Object Classification**: In this process, new objects are classified as belonging to one or more of your training categories by a trained model on a dataset of specific objects.
#
#
#
# * **Object identification**: In the object identification phase, our model will pinpoint a specific instance of an object. For instance, it may parse two faces in an image and identify Rohit Sharma and Virat Kohli, respectively.
#
#
# # How comp read imgs?
# * img -->rgb -->each have pixel val to matrcis compare numerical vals by using this read
#
#
# # two typical techniques to recognize the picture:
# * Images that just include the two colors black and white are known as grayscale images. Black is considered to have the lowest intensity, whereas white has the highest, according to the contrast assessment of intensity. The computer gives each pixel in the grayscale image a value dependent on how dark it is when we use it.
#
# * An RGB is a mixture of red, green, and blue that results in a new color. The computer extracts Each pixel's value, which then organizes the information into an array for interpretation.

# %% [markdown]
# # Read Write and Save
#
# * imread(): used to read img from loc
#
# cv2.imread(filename[,flag])
# Parameters:
# filename: Name of the file to be loaded
#
# flag: The flag specifies the color type of a loaded image
# The imread() function returns a matrix
#
#
#
#
# * imshow(name of screen, img it will display )
#
#
# * imwrite(): save the img --cv2.imwrite(filename, img[,params])
#
# image- Image to be saved.
#
# params- The following parameters are currently supported:
#
# For JPEG, quality can be from 0 to 100. The default value is 95.
# For PNG, quality can be the compress level from 0 to 9. The default value is 1.
# For PPM, PGM, or PBM, it can be a binary format flag 0 or 1. The default value is 1.
#
#
# * cv2.waitKey(0) # here paramenter inside waitkey handle the life duration of img
# This is necessary to be required so that the image doesn't close immediately.
# It will run continuously until the key press.

# %% [markdown]
# # READ WRITE SAVE VIDEO
#
# Steps:
#
# * use cv2.VideoCapture(0 to get a video captrue  obj for camera
# * set up an infinate while loop and use the read() method to read frames using above created obj
# * use cv2.imshow() method to show the frames in video
# * breaks the loop when use clicks a specifickey
# * in real time video monitoring system to ensure that the camers is opened and workiing properly we have isOPned()
# * strating camers . here in videoCpature() -0 denotes bitl in webcam while 1 will denote external webcams
#
#
# img-pixel , video-frame
#
# capture a video: VideoCapture() using ret,frame=cap.read() ---image if ret is true read a bew frame and loop
# if false end of video
#
#
# ** input files (cv2.VideoCapture(),cv2.imread() ---->opencv project --->output files (cv2.VideoWriter(),cv2.imwrite() **

# %%
pip install opencv-python

# %%
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread('/content/smile.jpg', 1)  # original img
img1 = cv2.resize(img1, (1280, 700))  # width, height

plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')  # Hide axis
plt.show()

print("Image in original value==\n",img1)
# Out:
# Image in original value==
#  [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
import cv2
from matplotlib import pyplot as plt

img11 = cv2.imread('/content/smile.jpg',0)  # ogray scale img --cv2.IMREAD_GRAYSCALE
img11= cv2.resize(img11, (1280, 700))  # width, height

plt.imshow(cv2.cvtColor(img11, cv2.COLOR_BGR2RGB))
plt.title('gray scale Image')
plt.axis('off')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

img111 = cv2.imread('/content/smile.jpg',-1)  # oalpha channel -- cv2.IMREAD_UNCHANGED
img111= cv2.resize(img111, (1280, 700))  # width, height

plt.imshow(cv2.cvtColor(img111, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')  # Hide axis
plt.show()

# %%
cv2.waitKey(0) # here paramenter inside waitkey handle the life duration of img
#This is necessary to be required so that the image doesn't close immediately.
#It will run continuously until the key press.
# Out:
# -1

# %%
import cv2

# read image as grey scale
img = cv2.imread('/content/smile.jpg', 1)


status = cv2.imwrite('/content/smilyyy.jpg',  img)
print("Image written to file-system : ", status)
# Out:
# Image written to file-system :  True
